# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

x = np.arange(5)
y = np.arange(5)
print("X", x)
print("Y", y)

plt.plot(x, y)

plt.show()
# Out:
# X [0 1 2 3 4]
# Y [0 1 2 3 4]

# %%
plt.plot(x, y, "xg")
plt.show()

# %%
data = np.array([1, 2, 1, 2, 5, 1, 2])
plt.title("My title")
plt.xlabel("x label")
plt.ylabel("y lable")
plt.plot(data)

plt.show()

# %%
data = np.array([1, 2, 1, 2, 5, 1, 2])
plt.title("My title")
plt.xlabel("x label")
plt.ylabel("y lable")
plt.axis([1, 4, -2, 7])
plt.plot(data)

plt.show()

# %%
plt.hist(data)
plt.show()
